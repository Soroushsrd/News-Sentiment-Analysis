# %%
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough
from langchain.prompts import ChatPromptTemplate

import os
from Bio import Entrez
from datetime import datetime
import re

# %%
os.environ['OPENAI_API_KEY'] = "Your_API"
llm = ChatOpenAI(model='gpt-4-1106-preview', temperature=1)

# %%
def get_entrez(keywords: list):
    """
    This function takes in a list of keywords and searches the pubmed database for related articles
    It would then return the abstract of articles found.
    :param keywords:
    :return: output
    """
    # Set your email for PubMed requests (required)
    Entrez.email = "www.bahraam2002@gmail.com"

    # Keywords list to search in PubMed
    keywords_list = keywords

    # Combine keywords with OR operator for PubMed query. you can also use AND
    keywords_query = ' OR '.join(keywords_list)

    # Get today's date in for the text file's name (YYYY/MM/DD)
    today_date = datetime.today().strftime('%Y-%m-%d')

    # All you need to search is the keywords query
    search_query = f'({keywords_query})'
    search_results = Entrez.read(
        Entrez.esearch(db="pubmed", term=search_query, retmax=20, datetype="pdat", reldate=90, usehistory="y"))
    webenv = search_results['WebEnv']
    query_key = search_results['QueryKey']
    id_list = search_results['IdList']
    all_summaries = []
    # Step 2: EFetch to retrieve titles based on the UIDs
    for i in id_list:
        fetch_handle = Entrez.efetch(db="pubmed", id=i, rettype="abstract", retmode="text", webenv=webenv,
                                     query_key=query_key)
        fetch_content = fetch_handle.read()
        all_summaries.append(fetch_content)  # Store title along with summary
    output = ''.join(all_summaries)
    return output

# %%
def parse_keywords(output):
    """
    Parses the output list from the llm so the output keywords could be seareched with get_entrez function
    :param output:
    :return: list(unique_keywords)
    """
    # Initialize an empty set to store unique keywords
    unique_keywords = set()

    # Split the output into lines
    lines = output['question'].strip().split('\n')

    # Iterate through each line
    for line in lines:
        # Extract keywords using regular expression
        keywords = re.findall(r'"([^"]*)"', line)

        # Add keywords to the set
        unique_keywords.update(keywords)

    # Convert the set to a list and return
    return list(unique_keywords)

# %%
def collapse_list_of_lists(list_of_lists):
    """
    Takes in a list of texts and joins them together
    :param list_of_lists:
    :return: content
    """
    content = []
    for l in list_of_lists:
        content.append("\n\n".join(l))
    return "\n\n".join(content)

# %%
def split_embeder_retrieve(text:str,question:str):
    """
    Takes in a text and query, splits the text, embeds it and then seareches the database for a related content
    :param text:
    :param question:
    :return: related documents
    """
    splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=300,chunk_overlap=50)
    splits=splitter.create_documents([text])
    documents = splitter.split_documents(splits)
    ids = [str(i) for i in range(1, len(documents) + 1)]
    vectorstore=Chroma.from_documents(documents=documents,embedding=OpenAIEmbeddings(),ids=ids)
    print(documents)
    print(len(vectorstore))
    # retriever=vectorstore.as_retriever()
    # retrieved=retriever.get_relevant_documents(question)
    retrieved= vectorstore.similarity_search(question)
    return retrieved

# %% [markdown]
# Next we have a set of prompts that are first used to create keywords based on the user's question and then to answer with a small article.

# %%
WRITER_SYSTEM_PROMPT = "You are an AI critical thinker research assistant. Your sole purpose is to write well written, critically acclaimed, objective and structured reports on given text."  # noqa: E501
# Report prompts from https://github.com/assafelovic/gpt-researcher/blob/master/gpt_researcher/master/prompts.py
RESEARCH_REPORT_TEMPLATE = """Information:
--------
{text}
--------
Using the above information, answer the following question or topic: "{question}" in a detailed report -- \
The report should focus on the answer to the question, should be well structured, informative, \
in depth, with facts and numbers if available and a minimum of 1,200 words.
You should strive to write the report as long as you can using all relevant and necessary information provided.
You must write the report with markdown syntax.
You MUST determine your own concrete and valid opinion based on the given information. Do NOT deter to general and meaningless conclusions.
Write all used source urls at the end of the report, and make sure to not add duplicated sources, but only one reference for each.
You must write the report in apa format.
Please do your best, this is very important to my career."""  # noqa: E501

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", WRITER_SYSTEM_PROMPT),
        ("user", RESEARCH_REPORT_TEMPLATE),
    ]
)

# %%
KEY_PROMPT = ChatPromptTemplate.from_messages(
    [
        (
            "user",
            "extract 3 important keywords from  the following question: "
            "{question}\n"
            "You must respond with a list of strings in the following format: "
            '["keywords1", "keywords2","keywords3"]'
            "for example if the question was What are the effects of protein intake on hypertrophy?"
            "then you could return such a list:"
            '["muscle hypertrophy","protein intake"]',
        ),
    ]
)

# %%
question=input('aks your question:\n')

# %%
"""
The chain below takes in the question and then creates a list of keywords which are used to create a context which the actual question would be answered upon.
"""
key_search = KEY_PROMPT | ChatOpenAI(model='gpt-4-1106-preview', temperature=1) | {
    'question': StrOutputParser()} | RunnablePassthrough.assign(
    text=lambda x: get_entrez(parse_keywords(x)))

output1=key_search.invoke(
        {
            "question":question
        }
    )
# print(output1)
# Out:
# {'question': '["exercise", "blood glucose", "affect"]', 'text': '1. Chem Commun (Camb). 2024 Apr 17. doi: 10.1039/d4cc01111b. Online ahead of\nprint.\n\nHalloysite-derived mesoporous silica with high ionic conductivity improves Li-S \nbattery performance.\n\nAo R(1), Zhu Z(1), Zhang S(1)(2), Zhang Q(2)(3), Yan C(1), Tu F(4), Li T(4), Li \nMG(5), Fu L(1)(2)(3), Tang A(1)(3), Yang H(1)(2)(3).\n\nAuthor information:\n(1)Engineering Research Center of Nano-Geomaterials of Ministry of Education, \nLaboratory of Advanced Mineral Materials, Faculty of Materials Science and \nChemistry, China University of Geosciences, Wuhan 430074, China. \ntangaidong@cug.edu.cn.\n(2)College of Chemistry and Chemical Engineering, Central South University, \nChangsha 410083, China. adtang@csu.edu.cn.\n(3)Hunan Key Laboratory of Mineral Materials and Application, School of Minerals \nProcessing and Bioengineering, Central South University, Changsha 410083, China. \nhmyang@csu.edu.cn.\n(4)Changsha Research Institute of Mining and Metallurgy Co. LTD., Changsha \n410012, P. R. China.\n(5)Division of Integrative Systems and Design, Department of Electronic and \nComputer Engineering, The Hong Kong University of Science and Technology, Clear \nWater Bay, Kowloon, Hong Kong SAR, P. R. China.\n\nThe slow Li+ transport rate in the thick sulfur cathode of the Li-S battery \naffects its capacity and cycling performance. Herein, Fe-doped highly ordered \nmesoporous silica material (Fe-HSBA-15) as a sulfur carrier of the Li-S battery \nshows high ion conductivity (1.10 mS cm-1) and Li+ transference number (0.77). \nThe Fe-HSBA-15/S cell has an initial capacity of up to 1216.7 mA h g-1 at 0.2C \nand good stability. Impressively, at a high sulfur load of 4.34 mg cm-2, the \nFe-HSBA-15/S cell still maintains an area specific capacity of 4.47 mA h cm-2 \nafter 100 cycles. This is because Fe-HSBA-15 improves the Li+ diffusion behavior \nthrough the ordered mesoporous structure. Theoretical calculations also \nconfirmed that the doping of iron enhances the adsorption of polysulfides, \nreduces the band gap and makes the catalytic activity stronger.\n\nDOI: 10.1039/d4cc01111b\nPMID: 386305321. JMIR Med Educ. 2024 Apr 17;10:e50118. doi: 10.2196/50118.\n\nDevelopment of Web-Based Education Modules to Improve Carer Engagement in Cancer \nCare: Design and User Experience Evaluation of the e-Triadic Oncology (eTRIO) \nModules for Clinicians, Patients, and Carers.\n\nLaidsaar-Powell R(1)(2), Giunta S(1), Butow P(1)(2), Keast R(1), Koczwara \nB(3)(4), Kay J(5), Jefford M(6), Turner S(7)(8), Saunders C(9), Schofield \nP(6)(10)(11), Boyle F(8)(12), Yates P(13), White K(14), Miller A(15), Butt Z(1), \nBonnaudet M(5)(16), Juraskova I(1)(2).\n\nAuthor information:\n(1)Centre for Medical Psychology & Evidence-based Decision-making, School of \nPsychology, The University of Sydney, Sydney, Australia.\n(2)Psycho-Oncology Co-operative Research Group, The University of Sydney, \nSydney, Australia.\n(3)Flinders Medical Centre, Adelaide, Australia.\n(4)College of Medicine and Public Health, Flinders University, Adelaide, \nAustralia.\n(5)School of Computer Science, The University of Sydney, Sydney, Australia.\n(6)Health Services Research and Implementation Science, Peter MacCallum Cancer \nCentre, Melbourne, Australia.\n(7)Department of Radiation Oncology, Westmead Hospital, Westmead, Australia.\n(8)Faculty of Medicine and Health, The University of Sydney, Sydney, Australia.\n(9)Department of Surgery, Royal Melbourne Hospital, University of Melbourne, \nMelbourne, Australia.\n(10)Department of Psychology and Iverson Health Innovation Research Institute, \nSwinburne University, Melbourne, Australia.\n(11)Sir Peter MacCallum Department of Oncology, The University of Melbourne, \nMelbourne, Australia.\n(12)Patricia Ritchie Centre for Cancer Care & Research, Mater Hospital, Sydney, \nAustralia.\n(13)Faculty of Health, Queensland University of Technology, Brisbane, Australia.\n(14)Susan Wakil S ...

# %%
#Lets use the retriever to find relevant documents
retrieved_docs= split_embeder_retrieve(output1['text'],question)
# Out:
# [Document(page_content='1. Chem Commun (Camb). 2024 Apr 17. doi: 10.1039/d4cc01111b. Online ahead of\nprint.\n\nHalloysite-derived mesoporous silica with high ionic conductivity improves Li-S \nbattery performance.\n\nAo R(1), Zhu Z(1), Zhang S(1)(2), Zhang Q(2)(3), Yan C(1), Tu F(4), Li T(4), Li \nMG(5), Fu L(1)(2)(3), Tang A(1)(3), Yang H(1)(2)(3).'), Document(page_content='Author information:\n(1)Engineering Research Center of Nano-Geomaterials of Ministry of Education, \nLaboratory of Advanced Mineral Materials, Faculty of Materials Science and \nChemistry, China University of Geosciences, Wuhan 430074, China. \ntangaidong@cug.edu.cn.\n(2)College of Chemistry and Chemical Engineering, Central South University, \nChangsha 410083, China. adtang@csu.edu.cn.\n(3)Hunan Key Laboratory of Mineral Materials and Application, School of Minerals \nProcessing and Bioengineering, Central South University, Changsha 410083, China. \nhmyang@csu.edu.cn.\n(4)Changsha Research Institute of Mining and Metallurgy Co. LTD., Changsha \n410012, P. R. China.\n(5)Division of Integrative Systems and Design, Department of Electronic and \nComputer Engineering, The Hong Kong University of Science and Technology, Clear \nWater Bay, Kowloon, Hong Kong SAR, P. R. China.'), Document(page_content='The slow Li+ transport rate in the thick sulfur cathode of the Li-S battery \naffects its capacity and cycling performance. Herein, Fe-doped highly ordered \nmesoporous silica material (Fe-HSBA-15) as a sulfur carrier of the Li-S battery \nshows high ion conductivity (1.10 mS cm-1) and Li+ transference number (0.77). \nThe Fe-HSBA-15/S cell has an initial capacity of up to 1216.7 mA h g-1 at 0.2C \nand good stability. Impressively, at a high sulfur load of 4.34 mg cm-2, the \nFe-HSBA-15/S cell still maintains an area specific capacity of 4.47 mA h cm-2 \nafter 100 cycles. This is because Fe-HSBA-15 improves the Li+ diffusion behavior \nthrough the ordered mesoporous structure. Theoretical calculations also \nconfirmed that the doping of iron enhances the adsorption of polysulfides, \nreduces the band gap and makes the catalytic activity stronger.\n\nDOI: 10.1039/d4cc01111b\nPMID: 386305321. JMIR Med Educ. 2024 Apr 17;10:e50118. doi: 10.2196/50118.'), Document(page_content='DOI: 10.1039/d4cc01111b\nPMID: 386305321. JMIR Med Educ. 2024 Apr 17;10:e50118. doi: 10.2196/50118.\n\nDevelopment of Web-Based Education Modules to Improve Carer Engagement in Cancer \nCare: Design and User Experience Evaluation of the e-Triadic Oncology (eTRIO) \nModules for Clinicians, Patients, and Carers.\n\nLaidsaar-Powell R(1)(2), Giunta S(1), Butow P(1)(2), Keast R(1), Koczwara \nB(3)(4), Kay J(5), Jefford M(6), Turner S(7)(8), Saunders C(9), Schofield \nP(6)(10)(11), Boyle F(8)(12), Yates P(13), White K(14), Miller A(15), Butt Z(1), \nBonnaudet M(5)(16), Juraskova I(1)(2).'), Document(page_content='Author information:\n(1)Centre for Medical Psychology & Evidence-based Decision-making, School of \nPsychology, The University of Sydney, Sydney, Australia.\n(2)Psycho-Oncology Co-operative Research Group, The University of Sydney, \nSydney, Australia.\n(3)Flinders Medical Centre, Adelaide, Australia.\n(4)College of Medicine and Public Health, Flinders University, Adelaide, \nAustralia.\n(5)School of Computer Science, The University of Sydney, Sydney, Australia.\n(6)Health Services Research and Implementation Science, Peter MacCallum Cancer \nCentre, Melbourne, Australia.\n(7)Department of Radiation Oncology, Westmead Hospital, Westmead, Australia.\n(8)Faculty of Medicine and Health, The University of Sydney, Sydney, Australia.\n(9)Department of Surgery, Royal Melbourne Hospital, University of Melbourne, \nMelbourne, Australia.\n(10)Department of Psychology and Iverson Health Innovation Research Institute, \nSwinburne University, Melbourne, Australia.\n(11)Sir Peter MacCallum Department of Oncology, The University of Melbourne, \nMelbourne, Australia.\n(12)Patricia Ritchie Centre for Cancer  ...
# 85

# %%
def format_docs(docs):
    """
    creates a final document based on the relevant data
    :param docs:
    :return: document
    """
    return "\n\n".join(doc.page_content for doc in docs)
formatted_docs=format_docs(retrieved_docs)

# %%
"""
rag_chain takes in the question and context so that it can answer the question fully. It will output an article with a list of references.
"""
rag_chain =  prompt | llm | StrOutputParser()
answer= rag_chain.invoke(
        {
            "question":question,
            "text":formatted_docs
        }
    )

# %%
print(answer)
# Out:
# # The Impact of Exercise on Blood Glucose Levels: A Critical Analysis
#
# ## Abstract
#
# Regular physical activity is widely acknowledged for its positive effects on overall health, and has been particularly associated with glucose metabolism regulation. The intricate relationship between exercise and blood glucose levels hinges on a set of physiological mechanisms that facilitate glucose transportation and utilization. While the provided information does not directly address the correlation between exercise and blood glucose levels, it does include data on the impact of exercise on other health-related outcomes, which may indirectly suggest benefits that could extend to glycemic control. This report aims to critically analyze available literature and data to elucidate how exercise affects blood glucose levels based on the given information and additional pertinent sources.
#
# ## Introduction
#
# The prevalence of metabolic disorders, such as diabetes, has prompted extensive research into lifestyle modifications that can mitigate these conditions. Exercise is a cornerstone intervention recommended to maintain euglycemia – the state of having normal blood glucose levels. It is critical to explore how exercise influences blood glucose control and to understand the mechanisms behind this relationship. The onset of depression, often associated with chronic illnesses like diabetes, has been noted to potentially decrease with regular muscle-strengthening exercise, indicating a multifaceted benefit of physical activity. This report endeavors to examine the connection between exercise and blood glucose regulation in detail.
#
# ## Materials and Methods
#
# To construct a comprehensive report, a cross-sectional analysis of scientific literature and clinical trial results was undertaken. Specifically, studies that addressed the impact of exercise on various health outcomes – including patient-reported outcomes, quality of life, and exercise-related outcomes – were reviewed. These past studies were identified from the provided information and related reputable databases, with a focus on how such outcomes could relate to blood glucose control.
#
# ## Discussion
#
# ### Physiological Mechanisms of Exercise on Glucose Metabolism
#
# Exercise influences blood glucose levels through multiple physiological mechanisms. During physical activity, muscle contractions increase the uptake of glucose from the bloodstream to be used as energy, thereby reducing blood glucose levels. This process is facilitated both by insulin-dependent and insulin-independent pathways. The latter is particularly important during exercise, as it allows muscles to utilize glucose effectively even in individuals with insulin sensitivity issues, such as those with type 2 diabetes.
#
# ### Impact of Aerobic and Resistance Exercise on Glycemic Control
#
# Aerobic exercise, such as walking, running, and cycling, has been shown to enhance insulin sensitivity and promote glucose uptake by muscle cells. Resistance training, which involves activities like weight lifting, similarly improves glycemic control by increasing muscle mass – a key determinant in resting metabolic rate and insulin sensitivity.
#
# ### Acute vs. Chronic Effects of Exercise on Glucose Levels
#
# The effects of exercise on blood glucose can be classified into acute (short-term) and chronic (long-term) adaptations. Acutely, exercise can lower blood glucose levels for several hours post-activity. Chronically, regular physical activity enhances the body’s ability to manage glucose effectively, thereby improving overall metabolic health and reducing the risk of hyperglycemia and diabetes.
#
# ### Exercise Recommendations for Glycemic Control
#
# Current guidelines advocate for a combination of both aerobic and resistance training to achieve optimal glycemic control. The intensity and duration of exercise are tailored to individual fitness levels and metabolic goals, with the consensus pointing towards at least 150 minutes of moderate to vigorous aerobic exercise weekly, supplemented by resistance training on two or more days.
#
# ### Analysis of Literature and Data
#
# While the presented information does not specifically address the effects of exercise on blood glucose, the positive outcome on exercise-related measures implies a likely favorable impact on glucose control. Quality-of-life improvements through physical activity further suggest an enhancement in metabolic conditions. The placebo-controlled trials cited offer an insight into how perceived benefits, in the absence of tangible interventions, can shift health outcomes – underscoring the importance of objectively measuring exercise’s effect on blood glucose.
#
# ### Limitations
#
# The inherent limitations of the secondary data used for this report include the lack of direct measurements and outcomes specific to blood glucose regulation. Moreover, the inter-individual variabilities in exercise response and glycemic control necessitate personalized approaches to diabetes management and prevent broad generalizations from being made.
#
# ## Conclusions
#
# This report underscores the critical role of exercise in the management and regulation of blood glucose levels, supported by physiological evidence and corroborated by broader health outcomes research. Although immediate data on exercise and blood glucose was not provided, the inference drawn from related health improvements suggests that regular, structured physical activity is a vital component of metabolic health strategies.
#
# ## Recommendations
#
# 1. Encourage the adoption of regular aerobic and resistance training regimes aimed at enhancing insulin sensitivity and glycemic control.
# 2. Further research should directly correlate exercise types, frequencies, and intensities with changes in blood glucose levels in diverse populations.
# 3. Health professionals should consider personalized exercise prescriptions to optimize metabolic health for individuals with or at risk of diabetes.
#
# ## References
#
# The reference URLs provided in the initial information are included below as the primary sources for the content within our discussion:
#
# - JMIR Human Factors: https://humanfactors.jmir.org
# - JMIR Public Health Surveill: https://publichealth.jmir.org
#
# For the purposes of this report, data was extrapolated and supplemented with additional academic research and reputable sources to better assess the relationship between exercise and blood glucose management.
#
# ## Acknowledgments
#
# The authors of the original research cited in the provided information are acknowledged for their contributions to the field of health outcomes and exercise-related research.
#
# This report is a result of an independent analysis and synthesizes the provided information with additional literature to form a comprehensive understanding of exercise's impact on blood glucose levels. The inferences and conclusions drawn are those of the report's authors and not necessarily reflective of the original authors' positions.
